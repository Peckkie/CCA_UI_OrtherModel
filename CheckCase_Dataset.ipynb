# %%
import pandas as pd
import os
import glob

# %%
import pandas as pd
# import data 
dataframe_train = pd.read_csv (r'/home/yupaporn/codes/USAI/Traindf_set1.csv')
dataframe_test = pd.read_csv (r'/home/yupaporn/codes/USAI/Testdf_set1.csv')
dataframe_train['split'] ='Train'
dataframe_test['split'] ='Test'
print(len(dataframe_train))
print(len(dataframe_test))
dff1 = pd.concat([dataframe_test,dataframe_train])
print(len(dff1))
# Out:
# 5257
# 1312
# 6569

# %%
train_abn = dataframe_train[dataframe_train['Class'] == 'Abnormal']
print(len(set(train_abn['Case'])))
# Out:
# 366

# %%
train_abn = dataframe_train[dataframe_train['Class'] != 'Abnormal']
print(len(set(train_abn['Case'])))
# Out:
# 289

# %%
test_abn = dataframe_test[dataframe_test['Class'] == 'Abnormal']
print(len(set(test_abn['Case'])))
# Out:
# 91

# %%
test_abn = dataframe_test[dataframe_test['Class'] != 'Abnormal']
print(len(set(test_abn['Case'])))
# Out:
# 71

# %%
train_abn = dataframe_train[dataframe_train['Class'] == 'Abnormal']
train_abn
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0              0           0.0    15           P3          P31  Abnormal
# 1              1           1.0    15           P1           P1  Abnormal
# 2              2           2.0    15           P2           P2  Abnormal
# 3              3           3.0    15           P4          P42  Abnormal
# 4              4           4.0    15           P4          P41  Abnormal
# ...          ...           ...   ...          ...          ...       ...
# 2247        1591           NaN   386           P7          P72  Abnormal
# 2248        1592           NaN   326           P7          P72  Abnormal
# 2249        1593           NaN   330           P7          P72  Abnormal
# 2250        1594           NaN   331           P7          P72  Abnormal
# 2251        1595           NaN   373           P7          P72  Abnormal
#
#      Sub_class                                          Path Full  \
# ...
