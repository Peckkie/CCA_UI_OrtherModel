# %%
import pandas as pd
import os
import glob

# %%
import pandas as pd
# import data 
dataframe_train1 = pd.read_csv (r'/home/yupaporn/codes/USAI/Traindf_fold1.csv')
dataframe_val1 = pd.read_csv (r'/home/yupaporn/codes/USAI/Validationdf_fold1.csv')
# dataframe_test1 = pd.read_csv (r'/home/yupaporn/codes/USAI/Testdf.csv')
dff1 = pd.concat([dataframe_val1,dataframe_train1])
print(len(dff1))
# Out:
# 5257

# %%
dff1.to_csv('/home/yupaporn/codes/USAI/Traindf_set1.csv', index=False)

# %% [markdown]
# ## Move img to train directory

# %%
dff1.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0           0           0.0    15           P3          P31  Abnormal
# 1           1           1.0    15           P1           P1  Abnormal
# 2           2           2.0    15           P2           P2  Abnormal
#
#   Sub_class                                          Path Full  \
# 0      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 1      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
# 2      AB01  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...
#
#                                            Path Crop Views  ...  \
# 0  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-B  ...
# 1  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A  ...
# 2  /media/tohn/HDD/VISION_dataset/USAI/ABnormal01...  FP-A  ...
#
#                                        originalImage   left    top  width  \
# 0  https://irisprodseatraining.blob.core.windows....   35.0   96.0  694.0
# ...

# %%
dff1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5257 entries, 0 to 4600
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     5257 non-null   int64
#  1   Unnamed: 0.1   656 non-null    float64
#  2   Case           5257 non-null   int64
#  3   Abs Position   5257 non-null   object
#  4   Sub Position   5257 non-null   object
#  5   Class          5257 non-null   object
#  6   Sub_class      5257 non-null   object
#  7   Path Full      5257 non-null   object
#  8   Path Crop      5257 non-null   object
#  9   Views          5257 non-null   object
#  10  fold           5257 non-null   int64
#  11  tagName        5257 non-null   object
#  12  originalImage  1823 non-null   object
#  13  left           1823 non-null   float64
#  14  top            1823 non-null   float64
#  15  width          1823 non-null   float64
#  16  height         1823 non-null   float64
# ...

# %%
dic = {"filename": []}
case = list()
aa =[]
m =dff1
path_old = m['Path Crop'].tolist() 
case = m['Case'].tolist() 
Views = m['Views'].tolist() 
Class = m['Class'].tolist() 
Position = m['Sub Position'].tolist() 
tagName = m['tagName'].tolist() 
AB = m['Sub_class'].tolist() 
#Train
train_Nor_dir = '/media/tohn/HDD/VISION_dataset/USAI/dataset1/train'
# fnames = path_old  
for i in range(len(path_old)):
    new_name = 'Case'+str(case[i])+'_'+Views[i]+'_'+Position[i]+'_'+Class[i]+'_'+tagName[i]+'_'+AB[i]+'.jpg'
    dst = os.path.join(train_Nor_dir,new_name)
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    a = dst.split('/')[-1]
    aa.append(a)
    dic["filename"].append(a)
    shutil.copyfile(path_old[i], dst)

# %%
dff1["FileName"] = aa

# %%
dff1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0              0           0.0    15           P3          P31  Abnormal
# 1              1           1.0    15           P1           P1  Abnormal
# 2              2           2.0    15           P2           P2  Abnormal
# 3              3           3.0    15           P4          P42  Abnormal
# 4              4           4.0    15           P4          P41  Abnormal
# ...          ...           ...   ...          ...          ...       ...
# 4596        4596           NaN   344           P3          P32    Normal
# 4597        4597           NaN   344           P4          P42    Normal
# 4598        4598           NaN   344           P5          P52    Normal
# 4599        4599           NaN   344           P6          P61    Normal
# 4600        4600           NaN   344           P8           P8    Normal
#
#      Sub_class                                          Path Full  \
# ...

# %%
dff1.to_csv('/home/yupaporn/codes/USAI/Traindf_set1.csv', index=False)

# %% [markdown]
# ### Testset

# %%
test = pd.read_csv (r'/home/yupaporn/codes/USAI/Testdf.csv')
test
# Out:
#       Unnamed: 0  Unnamed: 0.1  Case Abs Position Sub Position     Class  \
# 0            111           111    40           P1           P1  Abnormal
# 1            112           112    40           P2           P2  Abnormal
# 2            113           113    40           P4          P41  Abnormal
# 3            114           114    40           P5          P51  Abnormal
# 4            115           115    40           P3          P31  Abnormal
# ...          ...           ...   ...          ...          ...       ...
# 1307        6550          6550   350           P3          P32    Normal
# 1308        6551          6551   350           P4          P42    Normal
# 1309        6552          6552   350           P5          P52    Normal
# 1310        6553          6553   350           P6          P61    Normal
# 1311        6554          6554   350           P8           P8    Normal
#
#      Sub_class                                          Path Full  \
# ...

# %%
dic = {"filename": []}
case = list()
aa =[]
m =test
path_old = m['Path Crop'].tolist() 
case = m['Case'].tolist() 
Views = m['Views'].tolist() 
Class = m['Class'].tolist() 
Position = m['Sub Position'].tolist() 
tagName = m['tagName'].tolist() 
AB = m['Sub_class'].tolist() 
#Train
train_Nor_dir = '/media/tohn/HDD/VISION_dataset/USAI/dataset1/test'
# fnames = path_old  
for i in range(len(path_old)):
    new_name = 'Case'+str(case[i])+'_'+Views[i]+'_'+Position[i]+'_'+Class[i]+'_'+tagName[i]+'_'+AB[i]+'.jpg'
    dst = os.path.join(train_Nor_dir,new_name)
    if os.path.exists(dst):
        dst = dst+'cp.jpg'
    a = dst.split('/')[-1]
    aa.append(a)
    dic["filename"].append(a)
    shutil.copyfile(path_old[i], dst)

# %%
test["FileName"] = aa
test.to_csv('/home/yupaporn/codes/USAI/Testdf_set1.csv', index=False)
